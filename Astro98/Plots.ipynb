# %%
#Set up plotting libraries
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib notebook

import numpy as np
import os
import h5py
import matplotlib.gridspec as gridspec
import random
from astroML.correlation import two_point

cdm = h5py.File('Data/COLOR_CDM_DM_subHaloes_z0.00.hdf5', 'r')
wdm = h5py.File('Data/COLOR_WDM_DM_subHaloes_z0.00.hdf5', 'r')

print(cdm,wdm)
# Out:
# <HDF5 file "COLOR_CDM_DM_subHaloes_z0.00.hdf5" (mode r)> <HDF5 file "COLOR_WDM_DM_subHaloes_z0.00.hdf5" (mode r)>

# %%
img_list=[]
file_list = ['Corrfunc_Largest_Sorted', 'Corrfunc_Largest_Sorted2', 'Corrfunc_Largest_Sorted3',
             'Corrfunc_Largest_Sorted_Centrals', 'Corrfunc_Largest_Sorted_Centrals2', 'Corrfunc_Largest_Sorted_Centrals3']
for i in range(0,2):
    img_list.append(mpimg.imread('Images/Data2/' + file_list[i] +'.pdf'))
    
for i in range(3,5):
    img_list.append(mpimg.imread('Images/Data1/' + file_list[i] +'.pdf'))

# %%
fig, ax = plt.subplots(nrows=2,ncols=3)
ax = ax.flatten()

string_list = ['HII > 0.1', 'HII > 0.1',
               'H2 > 0.1', 'H2 > 0.1', ' ', ' ']

for image, i, string in zip(img_list, range(5), string_list):
        im = ax[i].imshow(image)
        ax[i].axis('off')
        ax[i].text(s = string, x = 10, y = 1150, color = 'white', fontsize = 6)

ax[0].set_title('Face On', fontsize = 10)
ax[1].set_title('Edge On', fontsize = 10)

savefig_args = {}
savefig_args['bbox_inches']='tight'
savefig_args['pad_inches']=0

#fig.set_facecolor('k')
fig.set_size_inches(5.5, 3.5)
fig.savefig('Plot',**savefig_args)

fig.tight_layout(pad=0,w_pad=0,h_pad=0)
fig.subplots_adjust(wspace=0.0,hspace=0.05)

# %%
CUTE_cdm_sorted = np.genfromtxt("corr_cdm_pos_sorted2.txt", usecols = (0,1))
CUTE_wdm_sorted = np.genfromtxt("corr_wdm_pos_sorted2.txt", usecols = (0,1))

grid = gridspec.GridSpec(2,1, height_ratios = [4,1])
grid.update(hspace = 0)
grid0 = plt.subplot(grid[0])
grid1 = plt.subplot(grid[1])

grid0.loglog(CUTE_cdm_sorted[:,0], CUTE_cdm_sorted[:,1], label = "Cold Dark Matter")
grid0.loglog(CUTE_wdm_sorted[:,0], CUTE_wdm_sorted[:,1], label = "Sterile Neutrino, 7 keV")
grid0.set_xlim(10**-2, 3e1)
grid0.set_ylim(10**-1.25, 10**2)
grid0.set_ylabel(r"$\xi$/Mpc", fontsize = 16)
grid0.legend()
grid0.minorticks_on()
grid0.set_title("0.1 Halo/Mpc$^{3}$", fontsize = 16)

grid1.semilogx(CUTE_wdm_sorted[:,0], CUTE_wdm_sorted[:,1]/CUTE_cdm_sorted[:,1])
grid1.set_xlabel("Radius/Mpc", fontsize = 16)
grid1.set_ylabel("Ratio")
grid1.axhline(y = 1, color = "grey", ls = "--")
grid1.set_xlim(10**-2, 3e1)
grid1.set_ylim(0.8, 1.2)
grid1.minorticks_on()

plt.show()
# Out:
# C:\Users\shife\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: RuntimeWarning: invalid value encountered in true_divide

# %%
fig = plt.figure(figsize=(10,10))
grid0 = fig.add_subplot(4,2,1)
grid1 = fig.add_subplot(4,2,3)
grid2 = fig.add_subplot(4,2,2)
grid3 = fig.add_subplot(4,2,4)
grid4 = fig.add_subplot(4,2,5)
grid5 = fig.add_subplot(4,2,7)
grid6 = fig.add_subplot(4,2,6)
grid7 = fig.add_subplot(4,2,8)
fig.subplots_adjust(hspace=0)

grid0.loglog(CUTE_cdm_sorted[:,0], CUTE_cdm_sorted[:,1], label = "Cold Dark Matter")
grid0.loglog(CUTE_wdm_sorted[:,0], CUTE_wdm_sorted[:,1], label = "Sterile Neutrino, 7 keV")
grid0.set_xlim(10**-2, 3e1)
grid0.set_ylim(10**-1.25, 10**2)
grid0.set_ylabel(r"$\xi$/Mpc", fontsize = 16)
grid0.legend()
grid0.minorticks_on()
grid0.set_title("0.1 Halo/Mpc$^{3}$", fontsize = 16)

grid1.semilogx(CUTE_wdm_sorted[:,0], CUTE_wdm_sorted[:,1]/CUTE_cdm_sorted[:,1])
grid1.set_xlabel("Radius/Mpc", fontsize = 16)
grid1.set_ylabel("Ratio")
grid1.axhline(y = 1, color = "grey", ls = "--")
grid1.set_xlim(10**-2, 3e1)
grid1.set_ylim(0.8, 1.2)
grid1.minorticks_on()

grid2.loglog(CUTE_cdm_sorted[:,0], CUTE_cdm_sorted[:,1], label = "Cold Dark Matter")
grid2.loglog(CUTE_wdm_sorted[:,0], CUTE_wdm_sorted[:,1], label = "Sterile Neutrino, 7 keV")
grid2.set_xlim(10**-0.75, 2e1)
grid2.set_ylim(10**-1, 10**1.75)
grid2.set_ylabel(r"$\xi$/Mpc", fontsize = 16)
grid2.legend()
grid2.minorticks_on()
grid2.set_title("0.001 Halo/Mpc$^{3}$", fontsize = 16)

grid3.semilogx(CUTE_wdm_sorted[:,0], CUTE_wdm_sorted[:,1]/CUTE_cdm_sorted[:,1])
grid3.set_xlabel("Radius/Mpc", fontsize = 16)
grid3.set_ylabel("Ratio")
grid3.axhline(y = 1, color = "grey", ls = "--")
grid3.set_xlim(10**-0.75, 2e1)
grid3.set_ylim(0.9, 1.19)
grid3.minorticks_on()

plt.show()

# %%
CUTE_cdm_sorted = np.genfromtxt("corr_cdm_pos_sorted2.txt", usecols = (0,1))
CUTE_wdm_sorted = np.genfromtxt("corr_wdm_pos_sorted2.txt", usecols = (0,1))

CUTE_cdm_sorted2 = np.genfromtxt("corr_cdm_pos_sorted3.txt", usecols = (0,1))
CUTE_wdm_sorted2 = np.genfromtxt("corr_wdm_pos_sorted3.txt", usecols = (0,1))

CUTE_cdm_sorted3 = np.genfromtxt("corr_cdm_pos_sorted_centrals2.txt", usecols = (0,1))
CUTE_wdm_sorted3 = np.genfromtxt("corr_wdm_pos_sorted_centrals2.txt", usecols = (0,1))

CUTE_cdm_sorted4 = np.genfromtxt("corr_cdm_pos_sorted_centrals3.txt", usecols = (0,1))
CUTE_wdm_sorted4 = np.genfromtxt("corr_wdm_pos_sorted_centrals3.txt", usecols = (0,1))

props = dict(facecolor='none', edgecolor='lightgrey', pad = 5.0)
textstr = '\n'.join((
    r'Data: Central and Satellite galaxies',
    r'Number Density: 0.1 Galaxy/Mpc$^{3}$'))
textstr2 = '\n'.join((
    r'Data: Central and Satellite galaxies',
    r'Number Density: 0.001 Galaxy/Mpc$^{3}$'))
textstr3 = '\n'.join((
    r'Data: Central galaxies',
    r'Number Density: 0.1 Galaxy/Mpc$^{3}$'))
textstr4 = '\n'.join((
    r'Data: Central galaxies',
    r'Number Density: 0.001 Galaxy/Mpc$^{3}$'))

plt.figure(figsize=(9,11))
grid0 = gridspec.GridSpec(2,1, height_ratios = [4,1])
grid0.update(hspace = 0, left=0.13, right=0.52, bottom = 0.54)
grid00 = plt.subplot(grid0[0])
grid01 = plt.subplot(grid0[1])

grid00.loglog(CUTE_cdm_sorted[:,0], CUTE_cdm_sorted[:,1], label = "Cold Dark Matter", linewidth = 5, color = "blue")
grid00.loglog(CUTE_wdm_sorted[:,0], CUTE_wdm_sorted[:,1], label = "Sterile Neutrino, 7 keV", linewidth = 5, color = "red")
#grid00.set_xlim(10**-2, 3e1)
#grid00.set_ylim(10**-1.25, 10**2)
grid00.set_ylabel(r"$\xi(r)$", fontsize = 22)
grid00.legend(fontsize = 11)
grid00.minorticks_on()
grid00.tick_params(labelsize=11)
# grid00.set_title("0.1 Halo/Mpc$^{3}$", fontsize = 16)
# grid00.text(0.005,0.25, "Includes subhalos", fontsize=10, color = "dimgrey")
grid00.text(0.04, 0.35, textstr, transform=grid00.transAxes, fontsize=11,
        verticalalignment='top', bbox=props)

grid01.semilogx(CUTE_wdm_sorted[:,0], CUTE_wdm_sorted[:,1]/CUTE_cdm_sorted[:,1],  linewidth = 5, color = "green")
#grid01.set_xlabel("Radius/Mpc", fontsize = 16)
grid01.set_ylabel("Ratio", fontsize = 13.75)
grid01.axhline(y = 1, color = "grey", ls = "--", linewidth = 2.5)
#grid01.set_xlim(10**-2, 3e1)
#grid01.set_ylim(0.8, 1.2)
grid01.minorticks_on()
grid01.tick_params(labelsize=11)
grid01.yaxis.grid(which = "both")

grid1 = gridspec.GridSpec(2,1, height_ratios = [4,1])
grid1.update(hspace = 0, left=0.6, right=0.99, bottom = 0.54)
grid10 = plt.subplot(grid1[0])
grid11 = plt.subplot(grid1[1])

grid10.loglog(CUTE_cdm_sorted2[:,0], CUTE_cdm_sorted2[:,1], label = "Cold Dark Matter",  linewidth = 5, color = "blue")
grid10.loglog(CUTE_wdm_sorted2[:,0], CUTE_wdm_sorted2[:,1], label = "Sterile Neutrino, 7 keV",  linewidth = 5, color = "red")
#grid10.set_xlim(10**-0.75, 2e1)
#grid10.set_ylim(10**-1, 10**1.75)
#grid10.set_ylabel(r"$\xi$/Mpc", fontsize = 16)
grid10.legend(fontsize = 11)
grid10.minorticks_on()
grid10.tick_params(labelsize=11)
# grid10.set_title("0.001 Halo/Mpc$^{3}$", fontsize = 16)
# grid10.text(0.005,0.25, "Includes subhalos", fontsize=10, color = "dimgrey")
grid10.text(0.04, 0.35, textstr2, transform=grid10.transAxes, fontsize=11,
        verticalalignment='top', bbox=props)

grid11.semilogx(CUTE_wdm_sorted2[:,0], CUTE_wdm_sorted2[:,1]/CUTE_cdm_sorted2[:,1],  linewidth = 5, color = "green")
#grid11.set_xlabel("Radius/Mpc", fontsize = 16)
#grid11.set_ylabel("Ratio")
grid11.axhline(y = 1, color = "grey", ls = "--", linewidth = 2.5)
#grid11.set_xlim(10**-0.75, 2e1)
#grid11.set_ylim(0.9, 1.19)
grid11.minorticks_on()
grid11.tick_params(labelsize=11)
grid11.yaxis.grid(which = "both")

grid2 = gridspec.GridSpec(2,1, height_ratios = [4,1])
grid2.update(hspace = 0, left=0.13, right=0.52, top = 0.46)
grid20 = plt.subplot(grid2[0])
grid21 = plt.subplot(grid2[1])

grid20.loglog(CUTE_cdm_sorted3[:,0], CUTE_cdm_sorted3[:,1], label = "Cold Dark Matter",  linewidth = 5, color = "blue")
grid20.loglog(CUTE_wdm_sorted3[:,0], CUTE_wdm_sorted3[:,1], label = "Sterile Neutrino, 7 keV",  linewidth = 5, color = "red")
#grid20.set_xlim(10**-1.25, 2e1)
#grid20.set_ylim(10**-1.25, 10**1.25)
grid20.set_ylabel(r"$\xi(r)$", fontsize = 22)
grid20.legend(fontsize = 11)
grid20.minorticks_on()
grid20.tick_params(labelsize=11)
#grid20.set_title("0.1 Halo/Mpc$^{3}$", fontsize = 16)
grid20.text(0.04, 0.155, textstr3, transform=grid20.transAxes, fontsize=11,
        verticalalignment='top', bbox=props)

grid21.semilogx(CUTE_wdm_sorted3[:,0], CUTE_wdm_sorted3[:,1]/CUTE_cdm_sorted3[:,1],  linewidth = 5, color = "green")
grid21.set_xlabel("Radius/Mpc", fontsize = 22)
grid21.set_ylabel("Ratio", fontsize = 13.75)
grid21.axhline(y = 1, color = "grey", ls = "--", linewidth = 2.5)
#grid21.set_xlim(10**-1.25, 2e1)
#grid21.set_ylim(0.8, 1.1)
grid21.minorticks_on()
grid21.tick_params(labelsize=11)
grid21.yaxis.grid(which = "both")

grid3 = gridspec.GridSpec(2,1, height_ratios = [4,1])
grid3.update(hspace = 0, left=0.6, right=0.99, top = 0.46)
grid30 = plt.subplot(grid3[0])
grid31 = plt.subplot(grid3[1])

grid30.loglog(CUTE_cdm_sorted4[:,0], CUTE_cdm_sorted4[:,1], label = "Cold Dark Matter",  linewidth = 5, color = "blue")
grid30.loglog(CUTE_wdm_sorted4[:,0], CUTE_wdm_sorted4[:,1], label = "Sterile Neutrino, 7 keV",  linewidth = 5, color = "red")
#grid30.set_xlim(10**-0.25, 2e1)
#grid30.set_ylim(10**-1, 10**1)
#grid30.set_ylabel(r"$\xi$/Mpc", fontsize = 16)
grid30.legend(fontsize = 11)
grid30.minorticks_on()
grid30.tick_params(labelsize=11)
#grid30.set_title("0.001 Halo/Mpc$^{3}$", fontsize = 16)
grid30.text(0.04, 0.155, textstr4, transform=grid30.transAxes, fontsize=11,
        verticalalignment='top', bbox=props)

grid31.semilogx(CUTE_wdm_sorted4[:,0], CUTE_wdm_sorted4[:,1]/CUTE_cdm_sorted4[:,1],  linewidth = 5, color = "green")
grid31.set_xlabel("Radius/Mpc", fontsize = 22)
#grid31.set_ylabel("Ratio")
grid31.axhline(y = 1, color = "grey", ls = "--", linewidth = 2.5)
#grid31.set_xlim(10**-0.25, 2e1)
#grid31.set_ylim(0.8, 1.1)
grid31.minorticks_on()
grid31.tick_params(labelsize=11)
grid31.yaxis.grid(which = "both")

for grid in [grid00, grid01, grid10, grid11, grid20, grid21, grid30, grid31]:
    grid.set_xlim(10**-1.75, 2e1)
    grid.set_ylim(10**-1.75, 10**2)

for grid in [grid01, grid11, grid21, grid31]:
    grid.set_ylim(0.9, 1.7)

plt.show()
plt.savefig("Images\Plot.pdf")
# Out:
# <img src="data:image/png;base64,..." width="900">
# C:\Users\shife\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# C:\Users\shife\Anaconda3\lib\site-packages\ipykernel_launcher.py:74: RuntimeWarning: invalid value encountered in true_divide
# C:\Users\shife\Anaconda3\lib\site-packages\ipykernel_launcher.py:101: RuntimeWarning: invalid value encountered in true_divide
# C:\Users\shife\Anaconda3\lib\site-packages\ipykernel_launcher.py:128: RuntimeWarning: divide by zero encountered in true_divide
# C:\Users\shife\Anaconda3\lib\site-packages\ipykernel_launcher.py:128: RuntimeWarning: invalid value encountered in true_divide
